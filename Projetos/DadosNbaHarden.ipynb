# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
DataBase = pd.read_csv('Harden.csv')

# %%
DataBase.head(
)
# Out:
#     Season  Age Team   Lg Pos   G  GS    MP   FG   FGA  ...  DRB  TRB  AST  \
# 0  2009-10   20  OKC  NBA  SG  76   0  1738  233   578  ...  197  244  137
# 1  2010-11   21  OKC  NBA  SG  82   5  2189  298   684  ...  213  255  176
# 2  2011-12   22  OKC  NBA  SG  62   2  1946  309   629  ...  222  252  229
# 3  2012-13   23  HOU  NBA  SG  78  78  2985  585  1337  ...  317  379  455
# 4  2013-14   24  HOU  NBA  SG  73  73  2777  549  1205  ...  283  344  446
#
#    STL  BLK  TOV   PF   PTS  EVOLUÇAO PTS POR ANO  Trp-Dbl
# 0   80   20  106  200   753                   753        0
# 1   92   24  106  207   998                  1751        0
# 2   62   15  137  150  1044                  2795        0
# 3  142   38  295  178  2023                  4818        1
# 4  115   29  265  177  1851                  6669        1
#
# [5 rows x 33 columns]

# %%
DataBase.columns
# Out:
# Index(['Season', 'Age', 'Team', 'Lg', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA',
#        'FG%', '3P', 'EVOLUÇAO 3P ANOS', '3PA', '3P%', '2P', '2PA', '2P%',
#        'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK',
#        'TOV', 'PF', 'PTS', 'EVOLUÇAO PTS POR ANO', 'Trp-Dbl'],
#       dtype='object')

# %%
plt.figure(figsize=(16,8))
plt.title('Pontuação total James Harden por Temporada')
sns.barplot(data=DataBase,x='Season',y='PTS')
plt.xticks(rotation=45, ha='right');

# %%
Data = DataBase.set_index('Season')

Data.head()
# Out:
#          Age Team   Lg Pos   G  GS    MP   FG   FGA  FG%  ...  DRB  TRB  AST  \
# Season                                                    ...
# 2009-10   20  OKC  NBA  SG  76   0  1738  233   578  403  ...  197  244  137
# 2010-11   21  OKC  NBA  SG  82   5  2189  298   684  436  ...  213  255  176
# 2011-12   22  OKC  NBA  SG  62   2  1946  309   629  491  ...  222  252  229
# 2012-13   23  HOU  NBA  SG  78  78  2985  585  1337  438  ...  317  379  455
# 2013-14   24  HOU  NBA  SG  73  73  2777  549  1205  456  ...  283  344  446
#
#          STL  BLK  TOV   PF   PTS  EVOLUÇAO PTS POR ANO  Trp-Dbl
# Season
# 2009-10   80   20  106  200   753                   753        0
# 2010-11   92   24  106  207   998                  1751        0
# 2011-12   62   15  137  150  1044                  2795        0
# 2012-13  142   38  295  178  2023                  4818        1
# 2013-14  115   29  265  177  1851                  6669        1
#
# [5 rows x 32 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1212285985.py in <cell line: 0>()
# ...

# %%
rebotesTotais = DataBase['TRB'].sum()

# %%
assistsTotais = DataBase['AST'].sum()

# %%
# Totais
pontosTotais = DataBase['PTS'].sum()
assistsTotais = DataBase['AST'].sum()
rebotesTotais = DataBase['TRB'].sum()

# Dados para o gráfico
categorias = ['Pontos', 'Assistências', 'Rebotes']
totais = [pontosTotais, assistsTotais, rebotesTotais]

# Gráfico de barras
plt.title('Totais de Pontos, Rebotes e Assistências - Carreira James Harden')
plt.bar(categorias, totais, color=['blue', 'green', 'orange'])

# Mostrar valores em cima das barras
for i, v in enumerate(totais):
    plt.text(i, v + (v*0.01), str(v), ha='center', fontweight='bold')

plt.show()

# %%
# Out:
# np.int64(8316)
